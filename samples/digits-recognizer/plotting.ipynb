# %%
import numpy as np
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
import matplotlib.pyplot as plt

# Load data + pull out images and lables
labeled_images = pd.read_csv("./data/digits-recognizer/train.csv")

images = labeled_images.iloc[0:, 1:]
labels = labeled_images.iloc[0:, :1]

# %%
pca = decomposition.PCA(n_components=2)
pca.fit(images)
two_d_images = pca.transform(images)

# %%
labels.values[:, 0]
# type(two_d_images[:, 0])
# Out:
# array([1, 0, 1, ..., 7, 6, 9])

# %%
from matplotlib.colors import ListedColormap
% matplotlib inline

colors = np.random.rand(10)

plt.scatter(x=two_d_images[:, 0], y=two_d_images[:, 1], c=labels.values[:, 0])
plt.show()
